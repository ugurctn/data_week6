# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name

    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 610

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=" + weather_api_key

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = url + "&q=" + city

    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

    # pause to avoid rate limiting
    time.sleep(1)

# Indicate that Data Loading is complete
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | illizi
# City not found. Skipping...
# Processing Record 2 of Set 1 | lihue
# City not found. Skipping...
# Processing Record 3 of Set 1 | vilyuchinsk
# City not found. Skipping...
# Processing Record 4 of Set 1 | ancud
# City not found. Skipping...
# Processing Record 5 of Set 1 | saipan
# City not found. Skipping...
# Processing Record 6 of Set 1 | mirzapur
# City not found. Skipping...
# Processing Record 7 of Set 1 | fisterra
# City not found. Skipping...
# Processing Record 8 of Set 1 | albany
# City not found. Skipping...
# Processing Record 9 of Set 1 | grytviken
# City not found. Skipping...
# Processing Record 10 of Set 1 | bredasdorp
# City not found. Skipping...
# Processing Record 11 of Set 1 | atafu village
# City not found. Skipping...
# Processing Record 12 of Set 1 | yanchep
# City not found. Skipping...
# Processing Record 13 of Set 1 | djamaa
# City not found. Skipping...
# Processing Record 14 of Set 1 | wuchuan
# City not found. Skipping...
# Processing Record 15 of Set 1 | gulbene
# City not found. Skipping...
# Processing Record 16 of Set 1 | la mitra
# City not found. Skipping...
# Processing Record 17 of Set 1 | yellowknife
# City not found. Skipping...
# Processing Record 18 of Set 1 | lompoc
# City not found. Skipping...
# Processing Record 19 of Set 1 | vorgashor
# City not found. Skipping...
# Processing Record 20 of Set 1 | tazovsky
# City not found. Skipping...
# Processing Record 21 of Set 1 | port-aux-francais
# City not found. Skipping...
# Processing Record 22 of Set 1 | buckeye
# City not found. Skipping...
# Processing Record 23 of Set 1 | san mariano
# City not found. Skipping...
# Processing Record 24 of Set 1 | port elizabeth
# City not found. Skipping...
# Processing Record 25 of Set 1 | waitangi
# City not found. Skipping...
# Processing Record 26 of Set 1 | vorkuta
# City not found. Skipping...
# Processing Record 27 of Set 1 | constantia
# City not found. Skipping...
# Processing Record 28 of Set 1 | howrah
# City not found. Skipping...
# Processing Record 29 of Set 1 | ponta delgada
# City not found. Skipping...
# Processing Record 30 of Set 1 | ust-nera
# City not found. Skipping...
# Processing Record 31 of Set 1 | edinburgh of the seven seas
# City not found. Skipping...
# Processing Record 32 of Set 1 | xilin hot
# City not found. Skipping...
# Processing Record 33 of Set 1 | suva
# City not found. Skipping...
# Processing Record 34 of Set 1 | gonzalez
# City not found. Skipping...
# Processing Record 35 of Set 1 | teknaf
# City not found. Skipping...
# Processing Record 36 of Set 1 | bilibino
# City not found. Skipping...
# Processing Record 37 of Set 1 | hawaiian paradise park
# City not found. Skipping...
# Processing Record 38 of Set 1 | aasiaat
# City not found. Skipping...
# Processing Record 39 of Set 1 | enewetak
# City not found. Skipping...
# Processing Record 40 of Set 1 | axim
# City not found. Skipping...
# Processing Record 41 of Set 1 | novodvinsk
# City not found. Skipping...
# Processing Record 42 of Set 1 | bethel
# City not found. Skipping...
# Processing Record 43 of Set 1 | palmer
# City not found. Skipping...
# Processing Record 44 of Set 1 | chonchi
# City not found. Skipping...
# Processing Record 45 of Set 1 | san patricio
# City not found. Skipping...
# Processing Record 46 of Set 1 | valparaiso
# City not found. Skipping...
# Processing Record 47 of Set 1 | kibre mengist
# City not found. Skipping...
# Processing Record 48 of Set 1 | nova sintra
# City not found. Skipping...
# Processing Record 49 of Set 1 | tamanrasset
# City not found. Skipping...
# Processing Record 50 of Set 1 | belo oriente
# City not found. Skipping...
# Processing Record 0 of Set 2 | motygino
# City not found. Skipping...
# Processing Record 1 of Set 2 | elverta
# City not found. Skipping...
# Processing Record 2 of Set 2 | baiquan
# City not found. Skipping...
# Processing Record 3 of Set 2 | college
# City not found. Skipping...
# Processing Record 4 of Set 2 | hermanus
# City not found. Skipping...
# Processing Record 5 of Set 2 | susuman
# City not found. Skipping...
# Processing Record 6 of Set 2 | ushuaia
# City not found. Skipping...
# Processing Record 7 of Set 2 | inhambane
# City not found. Skipping...
# Processing Record 8 of Set 2 | zaranj
# City not found. Skipping...
# Processing Record 9 of Set 2 | kattivakkam
# City not found. Skipping...
# Processing Record 10 of Set 2 | ribeira grande
# City not found. Skipping...
# Processing Record 11 of Set 2 | adamstown
# City not found. Skipping...
# Processing Record 12 of Set 2 | port mathurin
# City not found. Skipping...
# Processing Record 13 of Set 2 | petropavlovsk-kamchatsky
# City not found. Skipping...
# Processing Record 14 of Set 2 | bubaque
# City not found. Skipping...
# Processing Record 15 of Set 2 | porto franco
# City not found. Skipping...
# Processing Record 16 of Set 2 | santa ana
# City not found. Skipping...
# Processing Record 17 of Set 2 | ghadamis
# City not found. Skipping...
# Processing Record 18 of Set 2 | soio
# City not found. Skipping...
# Processing Record 19 of Set 2 | hamilton
# City not found. Skipping...
# Processing Record 20 of Set 2 | olonkinbyen
# City not found. Skipping...
# Processing Record 21 of Set 2 | taibet
# City not found. Skipping...
# Processing Record 22 of Set 2 | ugoofaaru
# City not found. Skipping...
# Processing Record 23 of Set 2 | west island
# City not found. Skipping...
# Processing Record 24 of Set 2 | camacupa
# City not found. Skipping...
# Processing Record 25 of Set 2 | borzya
# City not found. Skipping...
# Processing Record 26 of Set 2 | leninsk
# City not found. Skipping...
# Processing Record 27 of Set 2 | livramento do brumado
# City not found. Skipping...
# Processing Record 28 of Set 2 | mermoz boabab
# City not found. Skipping...
# Processing Record 29 of Set 2 | gurupi
# City not found. Skipping...
# Processing Record 30 of Set 2 | puerto ayora
# City not found. Skipping...
# Processing Record 31 of Set 2 | quellon
# City not found. Skipping...
# Processing Record 32 of Set 2 | shushenskoye
# City not found. Skipping...
# Processing Record 33 of Set 2 | kavaratti
# City not found. Skipping...
# Processing Record 34 of Set 2 | nikol'sk
# City not found. Skipping...
# Processing Record 35 of Set 2 | visby
# City not found. Skipping...
# Processing Record 36 of Set 2 | butwal
# City not found. Skipping...
# Processing Record 37 of Set 2 | lebu
# City not found. Skipping...
# Processing Record 38 of Set 2 | taiohae
# City not found. Skipping...
# Processing Record 39 of Set 2 | blackmans bay
# City not found. Skipping...
# Processing Record 40 of Set 2 | mochudi
# City not found. Skipping...
# Processing Record 41 of Set 2 | thompson
# City not found. Skipping...
# Processing Record 42 of Set 2 | bakanas
# City not found. Skipping...
# Processing Record 43 of Set 2 | punta arenas
# City not found. Skipping...
# Processing Record 44 of Set 2 | papatowai
# City not found. Skipping...
# Processing Record 45 of Set 2 | yaren
# City not found. Skipping...
# Processing Record 46 of Set 2 | 'aqrah
# City not found. Skipping...
# Processing Record 47 of Set 2 | san pedro pochutla
# City not found. Skipping...
# Processing Record 48 of Set 2 | badger
# City not found. Skipping...
# Processing Record 49 of Set 2 | port lincoln
# City not found. Skipping...
# Processing Record 0 of Set 3 | gohpur
# City not found. Skipping...
# Processing Record 1 of Set 3 | mar del plata
# City not found. Skipping...
# Processing Record 2 of Set 3 | avarua
# City not found. Skipping...
# Processing Record 3 of Set 3 | puerto deseado
# City not found. Skipping...
# Processing Record 4 of Set 3 | tralee
# City not found. Skipping...
# Processing Record 5 of Set 3 | wailua homesteads
# City not found. Skipping...
# Processing Record 6 of Set 3 | nyurba
# City not found. Skipping...
# Processing Record 7 of Set 3 | georgetown
# City not found. Skipping...
# Processing Record 8 of Set 3 | takamaka
# City not found. Skipping...
# Processing Record 9 of Set 3 | saint-philippe
# City not found. Skipping...
# Processing Record 10 of Set 3 | kualakapuas
# City not found. Skipping...
# Processing Record 11 of Set 3 | afif
# City not found. Skipping...
# Processing Record 12 of Set 3 | covington
# City not found. Skipping...
# Processing Record 13 of Set 3 | paita
# City not found. Skipping...
# Processing Record 14 of Set 3 | tiksi
# City not found. Skipping...
# Processing Record 15 of Set 3 | kodiak
# City not found. Skipping...
# Processing Record 16 of Set 3 | makoua
# City not found. Skipping...
# Processing Record 17 of Set 3 | tofol
# City not found. Skipping...
# Processing Record 18 of Set 3 | kudahuvadhoo
# City not found. Skipping...
# Processing Record 19 of Set 3 | tura
# City not found. Skipping...
# Processing Record 20 of Set 3 | luderitz
# City not found. Skipping...
# Processing Record 21 of Set 3 | taulaga
# City not found. Skipping...
# Processing Record 22 of Set 3 | happy valley-goose bay
# City not found. Skipping...
# Processing Record 23 of Set 3 | don sak
# City not found. Skipping...
# Processing Record 24 of Set 3 | isafjordur
# City not found. Skipping...
# Processing Record 25 of Set 3 | linxia chengguanzhen
# City not found. Skipping...
# Processing Record 26 of Set 3 | margaret river
# City not found. Skipping...
# Processing Record 27 of Set 3 | merizo village
# City not found. Skipping...
# Processing Record 28 of Set 3 | benalla
# City not found. Skipping...
# Processing Record 29 of Set 3 | vilyuysk
# City not found. Skipping...
# Processing Record 30 of Set 3 | nizhneudinsk
# City not found. Skipping...
# Processing Record 31 of Set 3 | puerto san carlos
# City not found. Skipping...
# Processing Record 32 of Set 3 | tranovaho
# City not found. Skipping...
# Processing Record 33 of Set 3 | saratamata
# City not found. Skipping...
# Processing Record 34 of Set 3 | callao
# City not found. Skipping...
# Processing Record 35 of Set 3 | utrik
# City not found. Skipping...
# Processing Record 36 of Set 3 | fortuna
# City not found. Skipping...
# Processing Record 37 of Set 3 | fuvahmulah
# City not found. Skipping...
# Processing Record 38 of Set 3 | necochea
# City not found. Skipping...
# Processing Record 39 of Set 3 | muynoq
# City not found. Skipping...
# Processing Record 40 of Set 3 | at taj
# City not found. Skipping...
# Processing Record 41 of Set 3 | wuchang
# City not found. Skipping...
# Processing Record 42 of Set 3 | muzayri'
# City not found. Skipping...
# Processing Record 43 of Set 3 | jamestown
# City not found. Skipping...
# Processing Record 44 of Set 3 | ji'an
# City not found. Skipping...
# Processing Record 45 of Set 3 | farmington
# City not found. Skipping...
# Processing Record 46 of Set 3 | afaahiti
# City not found. Skipping...
# Processing Record 47 of Set 3 | puerto natales
# City not found. Skipping...
# Processing Record 48 of Set 3 | alofi
# City not found. Skipping...
# Processing Record 49 of Set 3 | sitka
# City not found. Skipping...
# Processing Record 0 of Set 4 | kerikeri
# City not found. Skipping...
# Processing Record 1 of Set 4 | cairns city
# City not found. Skipping...
# Processing Record 2 of Set 4 | turpan
# City not found. Skipping...
# Processing Record 3 of Set 4 | merano
# City not found. Skipping...
# Processing Record 4 of Set 4 | jorpeland
# City not found. Skipping...
# Processing Record 5 of Set 4 | ouellah
# City not found. Skipping...
# Processing Record 6 of Set 4 | gamba
# City not found. Skipping...
# Processing Record 7 of Set 4 | i-n-salah
# City not found. Skipping...
# Processing Record 8 of Set 4 | elamanchili
# City not found. Skipping...
# Processing Record 9 of Set 4 | lan sak
# City not found. Skipping...
# Processing Record 10 of Set 4 | chhapar
# City not found. Skipping...
# Processing Record 11 of Set 4 | udachny
# City not found. Skipping...
# Processing Record 12 of Set 4 | hilo
# City not found. Skipping...
# Processing Record 13 of Set 4 | arno
# City not found. Skipping...
# Processing Record 14 of Set 4 | hithadhoo
# City not found. Skipping...
# Processing Record 15 of Set 4 | yelizovo
# City not found. Skipping...
# Processing Record 16 of Set 4 | tecozautla
# City not found. Skipping...
# Processing Record 17 of Set 4 | uglegorsk
# City not found. Skipping...
# Processing Record 18 of Set 4 | qidu
# City not found. Skipping...
# Processing Record 19 of Set 4 | grand falls-windsor
# City not found. Skipping...
# Processing Record 20 of Set 4 | nivala
# City not found. Skipping...
# Processing Record 21 of Set 4 | mossel bay
# City not found. Skipping...
# Processing Record 22 of Set 4 | khandyga
# City not found. Skipping...
# Processing Record 23 of Set 4 | kirakira
# City not found. Skipping...
# Processing Record 24 of Set 4 | rosario do sul
# City not found. Skipping...
# Processing Record 25 of Set 4 | yanam
# City not found. Skipping...
# Processing Record 26 of Set 4 | klyuchi
# City not found. Skipping...
# Processing Record 27 of Set 4 | nuku'alofa
# City not found. Skipping...
# Processing Record 28 of Set 4 | gilgit
# City not found. Skipping...
# Processing Record 29 of Set 4 | kushk
# City not found. Skipping...
# Processing Record 30 of Set 4 | pimentel
# City not found. Skipping...
# Processing Record 31 of Set 4 | dongola
# City not found. Skipping...
# Processing Record 32 of Set 4 | dhuusamarreeb
# City not found. Skipping...
# Processing Record 33 of Set 4 | peterhead
# City not found. Skipping...
# Processing Record 34 of Set 4 | freetown
# City not found. Skipping...
# Processing Record 35 of Set 4 | besancon
# City not found. Skipping...
# Processing Record 36 of Set 4 | isla vista
# City not found. Skipping...
# Processing Record 37 of Set 4 | qaqortoq
# City not found. Skipping...
# Processing Record 38 of Set 4 | san agustin de valle fertil
# City not found. Skipping...
# Processing Record 39 of Set 4 | salinas
# City not found. Skipping...
# Processing Record 40 of Set 4 | buon ma thuot
# City not found. Skipping...
# Processing Record 41 of Set 4 | la paz
# City not found. Skipping...
# Processing Record 42 of Set 4 | gokceada
# City not found. Skipping...
# Processing Record 43 of Set 4 | um jar al gharbiyya
# City not found. Skipping...
# Processing Record 44 of Set 4 | ilulissat
# City not found. Skipping...
# Processing Record 45 of Set 4 | katsuura
# City not found. Skipping...
# Processing Record 46 of Set 4 | stanley
# City not found. Skipping...
# Processing Record 47 of Set 4 | longyearbyen
# City not found. Skipping...
# Processing Record 48 of Set 4 | bengkulu
# City not found. Skipping...
# Processing Record 49 of Set 4 | bereket
# City not found. Skipping...
# Processing Record 0 of Set 5 | sorong
# City not found. Skipping...
# Processing Record 1 of Set 5 | arkhangel'sk
# City not found. Skipping...
# Processing Record 2 of Set 5 | cabo san lucas
# City not found. Skipping...
# Processing Record 3 of Set 5 | kingston
# City not found. Skipping...
# Processing Record 4 of Set 5 | ayvacik
# City not found. Skipping...
# Processing Record 5 of Set 5 | uturoa
# City not found. Skipping...
# Processing Record 6 of Set 5 | whitehorse
# City not found. Skipping...
# Processing Record 7 of Set 5 | dhemaji
# City not found. Skipping...
# Processing Record 8 of Set 5 | magadan
# City not found. Skipping...
# Processing Record 9 of Set 5 | al jawf
# City not found. Skipping...
# Processing Record 10 of Set 5 | marka
# City not found. Skipping...
# Processing Record 11 of Set 5 | wenshui
# City not found. Skipping...
# Processing Record 12 of Set 5 | ejido benito juarez
# City not found. Skipping...
# Processing Record 13 of Set 5 | la huerta
# City not found. Skipping...
# Processing Record 14 of Set 5 | aureilhan
# City not found. Skipping...
# Processing Record 15 of Set 5 | saint-pierre
# City not found. Skipping...
# Processing Record 16 of Set 5 | belyy yar
# City not found. Skipping...
# Processing Record 17 of Set 5 | greenville
# City not found. Skipping...
# Processing Record 18 of Set 5 | margate
# City not found. Skipping...
# Processing Record 19 of Set 5 | lockwood
# City not found. Skipping...
# Processing Record 20 of Set 5 | selfoss
# City not found. Skipping...
# Processing Record 21 of Set 5 | tyup
# City not found. Skipping...
# Processing Record 22 of Set 5 | puerto baquerizo moreno
# City not found. Skipping...
# Processing Record 23 of Set 5 | mamfe
# City not found. Skipping...
# Processing Record 24 of Set 5 | mitu
# City not found. Skipping...
# Processing Record 25 of Set 5 | sarakhs
# City not found. Skipping...
# Processing Record 26 of Set 5 | leava
# City not found. Skipping...
# Processing Record 27 of Set 5 | hidalgo
# City not found. Skipping...
# Processing Record 28 of Set 5 | martapura
# City not found. Skipping...
# Processing Record 29 of Set 5 | nolinsk
# City not found. Skipping...
# Processing Record 30 of Set 5 | new norfolk
# City not found. Skipping...
# Processing Record 31 of Set 5 | invercargill
# City not found. Skipping...
# Processing Record 32 of Set 5 | ust'-kulom
# City not found. Skipping...
# Processing Record 33 of Set 5 | rockland
# City not found. Skipping...
# Processing Record 34 of Set 5 | piacabucu
# City not found. Skipping...
# Processing Record 35 of Set 5 | novaya igirma
# City not found. Skipping...
# Processing Record 36 of Set 5 | sitangkai
# City not found. Skipping...
# Processing Record 37 of Set 5 | naugachhia
# City not found. Skipping...
# Processing Record 38 of Set 5 | arraial do cabo
# City not found. Skipping...
# Processing Record 39 of Set 5 | bardai
# City not found. Skipping...
# Processing Record 40 of Set 5 | colonia
# City not found. Skipping...
# Processing Record 41 of Set 5 | aripuana
# City not found. Skipping...
# Processing Record 42 of Set 5 | aniva
# City not found. Skipping...
# Processing Record 43 of Set 5 | tanhacu
# City not found. Skipping...
# Processing Record 44 of Set 5 | zhukovo
# City not found. Skipping...
# Processing Record 45 of Set 5 | kokoda
# City not found. Skipping...
# Processing Record 46 of Set 5 | alappuzha
# City not found. Skipping...
# Processing Record 47 of Set 5 | choibalsan
# City not found. Skipping...
# Processing Record 48 of Set 5 | crucecita
# City not found. Skipping...
# Processing Record 49 of Set 5 | gizo
# City not found. Skipping...
# Processing Record 0 of Set 6 | san antonio de pale
# City not found. Skipping...
# Processing Record 1 of Set 6 | vila franca do campo
# City not found. Skipping...
# Processing Record 2 of Set 6 | nuuk
# City not found. Skipping...
# Processing Record 3 of Set 6 | paphos
# City not found. Skipping...
# Processing Record 4 of Set 6 | tremseh
# City not found. Skipping...
# Processing Record 5 of Set 6 | mahina
# City not found. Skipping...
# Processing Record 6 of Set 6 | east london
# City not found. Skipping...
# Processing Record 7 of Set 6 | zhezqazghan
# City not found. Skipping...
# Processing Record 8 of Set 6 | anadyr
# City not found. Skipping...
# Processing Record 9 of Set 6 | lorengau
# City not found. Skipping...
# Processing Record 10 of Set 6 | hammerfest
# City not found. Skipping...
# Processing Record 11 of Set 6 | turan
# City not found. Skipping...
# Processing Record 12 of Set 6 | globe
# City not found. Skipping...
# Processing Record 13 of Set 6 | newman
# City not found. Skipping...
# Processing Record 14 of Set 6 | piton saint-leu
# City not found. Skipping...
# Processing Record 15 of Set 6 | cockburn town
# City not found. Skipping...
# Processing Record 16 of Set 6 | cidreira
# City not found. Skipping...
# Processing Record 17 of Set 6 | aykhal
# City not found. Skipping...
# Processing Record 18 of Set 6 | santa terezinha
# City not found. Skipping...
# Processing Record 19 of Set 6 | mariental
# City not found. Skipping...
# Processing Record 20 of Set 6 | talnakh
# City not found. Skipping...
# Processing Record 21 of Set 6 | hirara
# City not found. Skipping...
# Processing Record 22 of Set 6 | midoun
# City not found. Skipping...
# Processing Record 23 of Set 6 | lubango
# City not found. Skipping...
# Processing Record 24 of Set 6 | oltinko'l
# City not found. Skipping...
# Processing Record 25 of Set 6 | bontang
# City not found. Skipping...
# Processing Record 26 of Set 6 | chrysoupolis
# City not found. Skipping...
# Processing Record 27 of Set 6 | walvis bay
# City not found. Skipping...
# Processing Record 28 of Set 6 | pandan
# City not found. Skipping...
# Processing Record 29 of Set 6 | vernon
# City not found. Skipping...
# Processing Record 30 of Set 6 | pariaman
# City not found. Skipping...
# Processing Record 31 of Set 6 | farafangana
# City not found. Skipping...
# Processing Record 32 of Set 6 | mount isa
# City not found. Skipping...
# Processing Record 33 of Set 6 | tangalle
# City not found. Skipping...
# Processing Record 34 of Set 6 | iqaluit
# City not found. Skipping...
# Processing Record 35 of Set 6 | cinarli
# City not found. Skipping...
# Processing Record 36 of Set 6 | severo-yeniseyskiy
# City not found. Skipping...
# Processing Record 37 of Set 6 | codrington
# City not found. Skipping...
# Processing Record 38 of Set 6 | abdulino
# City not found. Skipping...
# Processing Record 39 of Set 6 | mildura
# City not found. Skipping...
# Processing Record 40 of Set 6 | el granada
# City not found. Skipping...
# Processing Record 41 of Set 6 | as sulayyil
# City not found. Skipping...
# Processing Record 42 of Set 6 | aflao
# City not found. Skipping...
# Processing Record 43 of Set 6 | prado
# City not found. Skipping...
# Processing Record 44 of Set 6 | petawawa
# City not found. Skipping...
# Processing Record 45 of Set 6 | kudymkar
# City not found. Skipping...
# Processing Record 46 of Set 6 | balcarce
# City not found. Skipping...
# Processing Record 47 of Set 6 | labytnangi
# City not found. Skipping...
# Processing Record 48 of Set 6 | balezino
# City not found. Skipping...
# Processing Record 49 of Set 6 | dalandzadgad
# City not found. Skipping...
# Processing Record 0 of Set 7 | aldama
# City not found. Skipping...
# Processing Record 1 of Set 7 | queenstown
# City not found. Skipping...
# Processing Record 2 of Set 7 | berdigestyakh
# City not found. Skipping...
# Processing Record 3 of Set 7 | haiku-pauwela
# City not found. Skipping...
# Processing Record 4 of Set 7 | northam
# City not found. Skipping...
# Processing Record 5 of Set 7 | boende
# City not found. Skipping...
# Processing Record 6 of Set 7 | dunedin
# City not found. Skipping...
# Processing Record 7 of Set 7 | keflavik
# City not found. Skipping...
# Processing Record 8 of Set 7 | maiwut
# City not found. Skipping...
# Processing Record 9 of Set 7 | fauske
# City not found. Skipping...
# Processing Record 10 of Set 7 | jabor
# City not found. Skipping...
# Processing Record 11 of Set 7 | nishinoomote
# City not found. Skipping...
# Processing Record 12 of Set 7 | laikit, laikit ii (dimembe)
# City not found. Skipping...
# Processing Record 13 of Set 7 | tabou
# City not found. Skipping...
# Processing Record 14 of Set 7 | robore
# City not found. Skipping...
# Processing Record 15 of Set 7 | gun barrel city
# City not found. Skipping...
# Processing Record 16 of Set 7 | santiago de cuba
# City not found. Skipping...

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          561
# Lat           561
# Lng           561
# Max Temp      561
# Humidity      561
# Cloudiness    561
# Wind Speed    561
# Country       561
# Date          561
# dtype: int64

# %%
# Display sample data
city_data_df.head()

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(
    city_data_df["Lat"],
    city_data_df["Max Temp"],
    edgecolor="black",
    linewidths=1,
    marker="o",
    alpha=0.8,
    label="Cities"
)

# Incorporate the other graph properties
plt.title("City Max Latitude vs. Temperature (%s)" % time.strftime("%Y-%m-%d"))
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (C)")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(
    city_data_df["Lat"],
    city_data_df["Humidity"],
    edgecolor="black",
    linewidths=1,
    marker="o",
    alpha=0.8,
    label="Cities"
)

# Incorporate the other graph properties
plt.title("City Latitude vs. Humidity (%s)" % time.strftime("%Y-%m-%d"))
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(
    city_data_df["Lat"],
    city_data_df["Cloudiness"],
    edgecolor="black",
    linewidths=1,
    marker="o",
    alpha=0.8,
    label="Cities"
)

# Incorporate the other graph properties
plt.title("City Latitude vs. Cloudiness (%s)" % time.strftime("%Y-%m-%d"))
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(
    city_data_df["Lat"],
    city_data_df["Wind Speed"],
    edgecolor="black",
    linewidths=1,
    marker="o",
    alpha=0.8,
    label="Cities"
)

# Incorporate the other graph properties
plt.title("City Latitude vs. Wind Speed (%s)" % time.strftime("%Y-%m-%d"))
plt.ylabel("Wind Speed (m/s)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def plot_linear_regression(x_values, y_values, title, text_coordinates):

    # Compute linear regression
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
    regress_values = x_values * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

    # Plot
    plt.scatter(x_values,y_values)
    plt.plot(x_values,regress_values,"r-")
    plt.annotate(line_eq,text_coordinates,fontsize=15,color="red")
    plt.xlabel("Latitude")
    plt.ylabel(title)
    plt.title(f"Latitude vs {title}")
    print(f"The r^2-value is: {rvalue**2}")
    plt.show()

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df.loc[(city_data_df["Lat"] >= 0)]

# Display sample data
northern_hemi_df.head()

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df.loc[(city_data_df["Lat"] < 0)]

# Display sample data
southern_hemi_df.head()

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Max Temp"]
plot_linear_regression(x_values, y_values, "Max Temp", (6, 0))

# %%
# Linear regression on Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Max Temp"]
plot_linear_regression(x_values, y_values, "Max Temp", (-55, 30))

# %% [markdown]
# **Discussion about the linear relationship:** The high `r^2` value indicates a strong correlation between latitude and max temperature. R^2 values ~ 0.5 indicate that there is a moderate correlation between the variables.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Humidity"]
plot_linear_regression(x_values, y_values, "Humidity", (50,10))

# %%
# Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Humidity"]
plot_linear_regression(x_values, y_values, "Humidity", (-50, 30))

# %% [markdown]
# **Discussion about the linear relationship:** The low `r^2` values indicate a weak to no relationship between humidity and latitude.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Cloudiness"]
plot_linear_regression(x_values, y_values, "Cloudiness", (40,10))
# Out:
# The r^2-value is: 0.006456908379763574

# %%
# Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Cloudiness"]
plot_linear_regression(x_values, y_values, "Cloudiness", (-30,30))
# Out:
# The r^2-value is: 0.018616831531634456

# %% [markdown]
# **Discussion about the linear relationship:** The low `r^2` values indicate a weak relationship between latitude and cloudiness.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Wind Speed"]
plot_linear_regression(x_values, y_values, "Wind Speed", (10,12))
# Out:
# The r^2-value is: 0.0017236249523139959

# %%
# Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Wind Speed"]
plot_linear_regression(x_values, y_values, "Wind Speed", (-50, 12))
# Out:
# The r^2-value is: 0.06495869418886388

# %% [markdown]
# **Discussion about the linear relationship:** The low `r^2` values indicate that there is no real relationship between wind speed and latitude. The difference between the hemispheres doesn't seem to be significant enough to comment upon.
